# %%
# %load_ext autoreload
# %autoreload 2
    
from matplotlib import pyplot as plt
from ipywidgets import interact, interactive, IntSlider, Layout, interact_manual, fixed
import ipywidgets as widgets
from IPython.display import display
import numpy as np

import pickle
from trackers import evaluate_hota
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
metrics_3 = pickle.load(open( '3_all_metrics.pkl', 'rb' ) )
metrics_3.keys()
# Out:
# dict_keys(['waterz_iou', 'stardist_iou', 'waterz_hung', 'stardist_hung', 'waterz_hung_cent'])

# %%
metrics_5 = pickle.load(open( '5_all_metrics.pkl', 'rb' ) )
metrics_5.keys()
# Out:
# dict_keys(['stardist_track', 'stardist_track_merged', 'array_labels'])

# %%
metrics_6 = pickle.load(open( '6_all_metrics.pkl', 'rb' ) )
metrics_6.keys()
# Out:
# dict_keys(['p34', 'p39', 'p42', 'p101', 'p473', 'array_labels'])

# %%
metrics_3['waterz_iou'].keys()
# Out:
# dict_keys(['HOTA', 'DetA', 'AssA', 'DetRe', 'DetPr', 'AssRe', 'AssPr', 'LocA', 'OWTA', 'HOTA_TP', 'HOTA_FN', 'HOTA_FP', 'HOTA(0)', 'LocA(0)', 'HOTALocA(0)'])

# %%
array_labels = metrics_6['array_labels']

# %%
plt.figure()

plt.plot(array_labels, [s for s in metrics_3['waterz_iou']['HOTA']], '.-', lw=2, label='WaterZ IoU')
plt.plot(array_labels, [s for s in metrics_3['stardist_iou']['HOTA']], '.-', lw=2, label='StarDist IoU')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung']['HOTA']], '.-', lw=2, label='WaterZ Hungarian IoU')
plt.plot(array_labels, [s for s in metrics_3['stardist_hung']['HOTA']], '.-', lw=2, label='StarDist Hungarian IoU')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung_cent']['HOTA']], '.-', lw=2, label='WaterZ Hungarian Centroid')

plt.plot(array_labels, [s for s in metrics_5['stardist_track']['HOTA']], '.-', lw=2, label='StarDist XYT')
plt.plot(array_labels, [s for s in metrics_5['stardist_track_merged']['HOTA']], '.-', lw=2, label='StarDist XYT Merged')

plt.plot(array_labels, [s for s in metrics_6['p34']['HOTA']], '.-', lw=2, label='Linajea P34')
plt.plot(array_labels, [s for s in metrics_6['p39']['HOTA']], '.-', lw=2, label='Linajea P39')
plt.plot(array_labels, [s for s in metrics_6['p42']['HOTA']], '.-', lw=2, label='Linajea P42')

#plt.xticks(hota2.array_labels)
plt.xlabel(r'alpha')
plt.ylabel('HOTA')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('7_all_hota.png')

# %%
plt.figure()

plt.plot(array_labels, [s for s in metrics_3['waterz_iou']['DetA']], '.-', lw=2, label='WaterZ IoU')
plt.plot(array_labels, [s for s in metrics_3['stardist_iou']['DetA']], '.-', lw=2, label='StarDist IoU')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung']['DetA']], '.-', lw=2, label='WaterZ Hungarian IoU')
plt.plot(array_labels, [s for s in metrics_3['stardist_hung']['DetA']], '.-', lw=2, label='StarDist Hungarian IoU')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung_cent']['DetA']], '.-', lw=2, label='WaterZ Hungarian Centroid')

plt.plot(array_labels, [s for s in metrics_5['stardist_track']['DetA']], '.-', lw=2, label='StarDist XYT')
plt.plot(array_labels, [s for s in metrics_5['stardist_track_merged']['DetA']], '.-', lw=2, label='StarDist XYT Merged')

plt.plot(array_labels, [s for s in metrics_6['p34']['DetA']], '.-', lw=2, label='Linajea P34')
plt.plot(array_labels, [s for s in metrics_6['p39']['DetA']], '.-', lw=2, label='Linajea P39')
plt.plot(array_labels, [s for s in metrics_6['p42']['DetA']], '.-', lw=2, label='Linajea P42')

#plt.xticks(hota2.array_labels)
plt.xlabel(r'alpha')
plt.ylabel('Detection Accuracy')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('7_all_deta.png')

# %%
plt.figure()

plt.plot(array_labels, [s for s in metrics_3['waterz_iou']['AssA']], '.-', lw=2, label='WaterZ IoU')
plt.plot(array_labels, [s for s in metrics_3['stardist_iou']['AssA']], '.-', lw=2, label='StarDist IoU')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung']['AssA']], '.-', lw=2, label='WaterZ IoU Hungarian')
plt.plot(array_labels, [s for s in metrics_3['stardist_hung']['AssA']], '.-', lw=2, label='StarDist IoU Hungarian')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung_cent']['AssA']], '.-', lw=2, label='WaterZ Centroid Hungarian')

plt.plot(array_labels, [s for s in metrics_5['stardist_track']['AssA']], '.-', lw=2, label='StarDist XYT')
plt.plot(array_labels, [s for s in metrics_5['stardist_track_merged']['AssA']], '.-', lw=2, label='StarDist XYT Merged')

plt.plot(array_labels, [s for s in metrics_6['p34']['AssA']], '.-', lw=2, label='Linajea P34')
plt.plot(array_labels, [s for s in metrics_6['p39']['AssA']], '.-', lw=2, label='Linajea P39')
plt.plot(array_labels, [s for s in metrics_6['p42']['AssA']], '.-', lw=2, label='Linajea P42')

#plt.xticks(hota2.array_labels)
plt.xlabel(r'alpha')
plt.ylabel('Assignment Accuracy')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('7_all_assa.png')

# %%
plt.figure()

plt.plot(array_labels, [s for s in metrics_3['waterz_iou']['LocA']], '.-', lw=2, label='WaterZ IoU')
plt.plot(array_labels, [s for s in metrics_3['stardist_iou']['LocA']], '.-', lw=2, label='StarDist IoU')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung']['LocA']], '.-', lw=2, label='WaterZ IoU Hungarian')
plt.plot(array_labels, [s for s in metrics_3['stardist_hung']['LocA']], '.-', lw=2, label='StarDist IoU Hungarian')
plt.plot(array_labels, [s for s in metrics_3['waterz_hung_cent']['LocA']], '.-', lw=2, label='WaterZ Centroid Hungarian')

plt.plot(array_labels, [s for s in metrics_5['stardist_track']['LocA']], '.-', lw=2, label='StarDist XYT')
plt.plot(array_labels, [s for s in metrics_5['stardist_track_merged']['LocA']], '.-', lw=2, label='StarDist XYT Merged')

plt.plot(array_labels, [s for s in metrics_6['p34']['LocA']], '.-', lw=2, label='Linajea P34')
plt.plot(array_labels, [s for s in metrics_6['p39']['LocA']], '.-', lw=2, label='Linajea P39')
plt.plot(array_labels, [s for s in metrics_6['p42']['LocA']], '.-', lw=2, label='Linajea P42')

#plt.xticks(hota2.array_labels)
plt.xlabel(r'alpha')
plt.ylabel('Localization Accuracy')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('7_all_loca.png')

# %%
m = metrics_3['waterz_iou']
print('WaterZ IoU & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_3['stardist_iou']
print('StarDist IoU & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_3['waterz_hung']
print('WaterZ Hungarian IoU & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_3['stardist_hung']
print('StarDist Hungarian IoU & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_3['waterz_hung_cent']
print('StarDist Hungarian Centroid & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_5['stardist_track']
print('StarDist XYT & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_5['stardist_track_merged']
print('StarDist XYT Merged & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_6['p34']
print('Linajea P34 & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_6['p39']
print('Linajea P39 & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
m = metrics_6['p42']
print('Linajea P42 & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f ' % ( np.average(m['DetA']), np.average(m['DetPr']), np.average(m['DetRe']), np.average(m['AssA']), np.average(m['AssPr']), np.average(m['AssRe']), np.average(m['LocA']), np.average(m['HOTA']) ))
# Out:
# WaterZ IoU & 0.501 & 0.739 & 0.605 & 0.802 & 0.905 & 0.848 & 0.952 & 0.633
# StarDist IoU & 0.315 & 0.545 & 0.369 & 0.619 & 0.694 & 0.667 & 0.744 & 0.439
# WaterZ Hungarian IoU & 0.501 & 0.739 & 0.605 & 0.689 & 0.732 & 0.854 & 0.952 & 0.587
# StarDist Hungarian IoU & 0.364 & 0.635 & 0.408 & 0.645 & 0.694 & 0.715 & 0.773 & 0.482
# StarDist Hungarian Centroid & 0.499 & 0.737 & 0.604 & 0.486 & 0.585 & 0.682 & 0.952 & 0.492
# StarDist XYT & 0.304 & 0.409 & 0.452 & 0.383 & 0.560 & 0.457 & 0.734 & 0.339
# StarDist XYT Merged & 0.257 & 0.576 & 0.283 & 0.534 & 0.650 & 0.597 & 0.729 & 0.367
# Linajea P34 & 0.421 & 0.555 & 0.616 & 0.880 & 0.901 & 0.939 & 0.898 & 0.602
# Linajea P39 & 0.414 & 0.560 & 0.596 & 0.903 & 0.919 & 0.956 & 0.896 & 0.606
# Linajea P42 & 0.327 & 0.508 & 0.453 & 0.802 & 0.839 & 0.884 & 0.852 & 0.506

# %%
from_i = 0
max_i = 13
print(array_labels[max_i])
m = metrics_3['waterz_iou']
print('WaterZ IoU & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f\\\\\\hline' % ( np.average(m['DetA'][from_i:max_i]), np.average(m['DetPr'][from_i:max_i]), np.average(m['DetRe'][from_i:max_i]), np.average(m['AssA'][from_i:max_i]), np.average(m['AssPr'][from_i:max_i]), np.average(m['AssRe'][from_i:max_i]), np.average(m['LocA'][from_i:max_i]), np.average(m['HOTA'][from_i:max_i]) ))
m = metrics_3['stardist_iou']
print('StarDist IoU & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f\\\\\\hline' % ( np.average(m['DetA'][from_i:max_i]), np.average(m['DetPr'][from_i:max_i]), np.average(m['DetRe'][from_i:max_i]), np.average(m['AssA'][from_i:max_i]), np.average(m['AssPr'][from_i:max_i]), np.average(m['AssRe'][from_i:max_i]), np.average(m['LocA'][from_i:max_i]), np.average(m['HOTA'][from_i:max_i]) ))
m = metrics_6['p34']
print('Linajea P34 & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f\\\\\\hline' % ( np.average(m['DetA'][from_i:max_i]), np.average(m['DetPr'][from_i:max_i]), np.average(m['DetRe'][from_i:max_i]), np.average(m['AssA'][from_i:max_i]), np.average(m['AssPr'][from_i:max_i]), np.average(m['AssRe'][from_i:max_i]), np.average(m['LocA'][from_i:max_i]), np.average(m['HOTA'][from_i:max_i]) ))
m = metrics_6['p39']
print('Linajea P34 & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f & %.3f\\\\\\hline' % ( np.average(m['DetA'][from_i:max_i]), np.average(m['DetPr'][from_i:max_i]), np.average(m['DetRe'][from_i:max_i]), np.average(m['AssA'][from_i:max_i]), np.average(m['AssPr'][from_i:max_i]), np.average(m['AssRe'][from_i:max_i]), np.average(m['LocA'][from_i:max_i]), np.average(m['HOTA'][from_i:max_i]) ))
# Out:
# 0.7000000000000001
# WaterZ IoU & 0.535 & 0.773 & 0.634 & 0.823 & 0.922 & 0.861 & 0.938 & 0.663\\\hline
# StarDist IoU & 0.489 & 0.838 & 0.538 & 0.857 & 0.930 & 0.892 & 0.727 & 0.647\\\hline
# Linajea P34 & 0.487 & 0.621 & 0.689 & 0.868 & 0.887 & 0.941 & 0.862 & 0.650\\\hline
# Linajea P34 & 0.477 & 0.623 & 0.664 & 0.898 & 0.910 & 0.963 & 0.858 & 0.653\\\hline
